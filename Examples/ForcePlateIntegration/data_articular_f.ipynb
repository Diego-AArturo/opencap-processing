# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

# %%
print('Datos body wheigt (BD)')
display(pd.read_excel('tablas_af\Tablas_BD.xlsx', sheet_name='Senta90'))
print('Datos Newton (NW)')
display(pd.read_excel('tablas_af\Tablas_NW.xlsx', sheet_name='Senta90'))
# Out:
# Datos body wheigt (BD)
#    Sujeto  PESO  F1TIME  F1-RODSAGITAL D  FcompresivasF_T1  \
# 0       5  60.0   8.750            8.258          1.597435
# 1      12  61.3   3.950            4.633          1.809646
# 2      14  54.1   5.083            5.590          1.058919
# 3      20  58.0   5.183            5.071          0.671369
# 4      22  64.0   8.433            6.047          1.270447
# 5      24  63.0   4.833            5.443          1.921932
#
#    FanteroposteiorF_T1  FmedilateralesF_T1  FcompresivasP_T1  \
# 0            -0.154033            0.086813         -0.353545
# 1            -0.090697            0.045046          0.017422
# 2            -0.011715           -0.070583          0.100647
# 3             0.464133           -0.079775          0.409490
# 4             0.302624            0.002060          0.225658
# 5             0.160905            0.041472          0.226710
#
#    FanteroposteiorP_T1  FmedilateralesP_T1  ...  FcompresivasP_T3  \
# 0            -0.643425           -0.030875  ...         -0.022298
# 1            -0.684080           -0.017717  ...         -0.022027
# 2             0.046283            0.025000  ...          0.623423
# 3             0.469752            0.103811  ...         -0.002703
# 4            -0.058522            0.118048  ...         -0.277014
# 5            -0.567783            0.080010  ...          0.934113
#
#    FanteroposteiorP_T3  FmedilateralesP_T3  F3-RODSAGITAL I  \
# 0            -0.103593            0.019380            5.543
# 1            -0.119850            0.008245            6.698
# 2             0.872056            0.117588            0.000
# 3             0.077675           -0.000176           12.914
# 4            -1.057606            0.034139           11.873
# 5             0.303606            0.208560           10.288
#
#    FcompresivasF_1_T3  FanteroposteiorF_1_T3  FmedilateralesF_1_T3  \
# 0            0.930654               0.071498             -0.010522
# 1            1.775539               0.191826              0.050207
# 2            0.518178               0.658598              0.122175
# 3            0.769876              -0.141118              0.043572
# 4            2.042242              -0.009574             -0.058962
# 5            0.790605               0.590143              0.060592
#
#    FcompresivasP_1_T3  FanteroposteiorP_1_T3  FmedilateralesP_1_T3
# 0            0.001182              -0.153677             -0.022092
# 1           -0.044730              -0.109814             -0.005129
# 2            0.664702               0.907463             -0.133700
# 3           -0.043003              -0.044244              0.006399
# 4           -0.200016              -0.788741             -0.026283
# 5            0.781721               0.549273             -0.133767
#
# [6 rows x 47 columns]
# Datos Newton (NW)
#    Sujeto  PESO  F1TIME  F1-RODSAGITAL D  FcompresivasF_T1  \
# 0       5  60.0   8.750            8.258        940.250122
# 1      12  61.3   3.950            4.633       1088.235847
# 2      14  54.1   5.083            5.590        561.990630
# 3      20  58.0   5.183            5.071        381.995337
# 4      22  64.0   8.433            6.047        797.637270
# 5      24  63.0   4.833            5.443       1187.811351
#
#    FanteroposteiorF_T1  FmedilateralesF_T1  FcompresivasP_T1  \
# 0           -90.663819           51.098420       -208.096766
# 1           -54.540881           27.088618         10.477007
# 2            -6.217435          -37.459731         53.415490
# 3           264.082471          -45.390571        232.991726
# 4           189.999737            1.293120        141.677087
# 5            99.443895           25.631245        140.113680
#
#    FanteroposteiorP_T1  FmedilateralesP_T1  ...  FcompresivasP_T3  \
# 0          -378.720187          -18.172875  ...        -13.124390
# 1          -411.373507          -10.654414  ...        -13.245903
# 2            24.563157           13.267761  ...        330.863843
# 3           267.279635           59.066621  ...         -1.537959
# 4           -36.742259           74.115237  ...       -173.920256
# 5          -350.907074           49.448402  ...        577.309679
#
#    FanteroposteiorP_T3  FmedilateralesP_T3  F3-RODSAGITAL I  \
# 0           -60.974887           11.407057            5.543
# 1           -72.072327            4.957934            6.698
# 2           462.818604           62.406215            0.000
# 3            44.195267           -0.099962           12.914
# 4          -664.007321           21.434105           11.873
# 5           187.637652          128.896143           10.288
#
#    FcompresivasF_1_T3  FanteroposteiorF_1_T3  FmedilateralesF_1_T3  \
# 0          547.783182              42.083644             -6.193309
# 1         1067.725948             115.355083             30.192349
# 2          275.007691             349.531627             64.840784
# 3          438.043763             -80.293597             24.791468
# 4         1282.200904              -6.011040            -37.018451
# 5          488.617356             364.726283             37.447556
#
#    FcompresivasP_1_T3  FanteroposteiorP_1_T3  FmedilateralesP_1_T3
# 0            0.695858             -90.454066            -13.003451
# 1          -26.898295             -66.037154             -3.084229
# 2          352.771370             481.609743            -70.957311
# 3          -24.467583             -25.173798              3.640640
# 4         -125.578246            -495.203192            -16.501274
# 5          483.127080             339.467406            -82.671792
#
# [6 rows x 47 columns]

# %%
import pandas as pd
import re

# ──────────────────── 1. Cargar archivos ────────────────────
bd = pd.read_excel('tablas_af/Tablas_BD.xlsx', sheet_name='Senta60 ')   # %BW
nw = pd.read_excel('tablas_af/Tablas_NW.xlsx', sheet_name='Senta60 ')   # N

# ──────────────────── 2. Función de normalización de nombres ────────────────────
def normalizar_columnas(df):
    ren = {}
    for col in df.columns:
        s = col.upper().replace('-', '').replace(' ', '')
        # RODSAGITAL  (ej.: F1RODSAGITALD  ó  F1_RODSAGITALD  ó  F1-RODSAGITAL D)
        m = re.match(r'(F\d)_?RODSAGITAL([DI])', s)
        if m:
            fase   = m.group(1)         # F1, F2, F3...
            pierna = m.group(2)         # D o I
            ren[col] = f'{fase}-RODSAGITAL {pierna}'
        else:
            ren[col] = col   # sin cambios
    return df.rename(columns=ren)
# print('1 ',bd.columns[:10])
bd = normalizar_columnas(bd)
nw = normalizar_columnas(nw)
# print('2 ',bd.columns[:10])
# ──────────────────── 3. Añadir unidad a columnas de fuerza ────────────────────
force_regex = r'^F(?!\d*TIME)(?!\d*-?RODSAGITAL).*'   # look-ahead negativo
fuerza_bd = bd.filter(regex=force_regex).columns
fuerza_nw = nw.filter(regex=force_regex).columns

bd = bd.rename(columns={c: f'{c}(BD)' for c in fuerza_bd})   # Body-weight (%BW)
nw = nw.rename(columns={c: f'{c}(NW)' for c in fuerza_nw})   # Newton (N)
# print('3 ',bd.columns)
# ──────────────────── 4. Eliminar RODSAGITAL duplicados de la tabla NW ────────────────────
rod_cols = [f'F{i}-RODSAGITAL {p}' for i in (1, 2, 3) for p in ('D', 'I')]
nw = nw.drop(columns=[c for c in rod_cols if c in nw.columns])

# ──────────────────── 5. Unir DataFrames ────────────────────
# Si el peso coincide exactamente:
common_cols = ['PESO', 'F1TIME','F2TIME','F3TIME']  # Puedes incluir F2TIME o F3TIME si existen

df_final = (
    bd
    .merge(nw.drop(columns=[c for c in common_cols if c in nw.columns]), on=['Sujeto'], how='inner')
    .sort_values('Sujeto')
    .reset_index(drop=True)
)


# ► df_final ahora contiene:
#   • Una sola columna para cada RODSAGITAL (F1, F2, F3; D / I).
#   • Todas las columnas de fuerza dos veces: “… (BD)” y “… (NW)”.
#   • Cada fila corresponde al mismo sujeto y peso.

# ──────────────────── 6. Guardar o inspeccionar ────────────────────
# print('final ',df_final.columns)
# df_final
# Out:
# 3  Index(['Sujeto', 'PESO', 'F1TIME', 'F1-RODSAGITAL D', 'FcompresivasF_T1(BD)',
#        'FanteroposteiorF_T1(BD)', 'FmedilateralesF_T1(BD)',
#        'FcompresivasP_T1(BD)', 'FanteroposteiorP_T1(BD)',
#        'FmedilateralesP_T1(BD)', 'F1-RODSAGITAL I', 'FcompresivasF_1_T1(BD)',
#        'FanteroposteiorF_1_T1(BD)', 'FmedilateralesF_1_T1(BD)',
#        'FcompresivasP_1_T1(BD)', 'FanteroposteiorP_1_T1(BD)',
#        'FmedilateralesP_1_T1(BD)', 'F2TIME', 'F2-RODSAGITAL D',
#        'FcompresivasF_T2(BD)', 'FanteroposteiorF_T2(BD)',
#        'FmedilateralesF_T2(BD)', 'FcompresivasP_T2(BD)',
#        'FanteroposteiorP_T2(BD)', 'FmedilateralesP_T2(BD)', 'F2-RODSAGITAL I',
#        'FcompresivasF_1_T2(BD)', 'FanteroposteiorF_1_T2(BD)',
#        'FmedilateralesF_1_T2(BD)', 'FcompresivasP_1_T2(BD)',
#        'FanteroposteiorP_1_T2(BD)', 'FmedilateralesP_1_T2(BD)', 'F3TIME',
#        'F3-RODSAGITAL D', 'FcompresivasF_T3(BD)', 'FanteroposteiorF_T3(BD)',
#        'FmedilateralesF_T3(BD)', 'FcompresivasP_T3(BD)',
#        'FanteroposteiorP_T3(BD)', 'FmedilateralesP_T3(BD)', 'F3-RODSAGITAL I',
#        'FcompresivasF_1_T3(BD)', 'FanteroposteiorF_1_T3(BD)',
#        'FmedilateralesF_1_T3(BD)', 'FcompresivasP_1_T3(BD)',
#        'FanteroposteiorP_1_T3(BD)', 'FmedilateralesP_1_T3(BD)'],
#       dtype='object')

# %%
df = df_final

df_mod = df.copy()

# Ejes y fases a procesa

df_stas= df_mod.describe().loc[['mean','std']].T
df_stas['cv'] = (df_stas['std'] / np.abs(df_stas['mean'])).round(2)
fases = ['F1', 'F2', 'F3']
df_stas = df_stas.T
df_stas.drop(columns=[f"{fase}TIME" for fase in fases], inplace=True)
df_stas.drop(columns=['PESO'], inplace=True)
df_stas = df_stas.T
df_stas['media(ds)'] = df_stas['mean'].round(3).astype(str) + ' (±' + df_stas['std'].round(2).astype(str) + ')'

# %%
df_stas
# Out:
#                                  mean         std     cv          media(ds)
# Sujeto                      16.166667    7.167054   0.44     16.167 (±7.17)
# F1-RODSAGITAL D              5.840333    1.277332   0.22       5.84 (±1.28)
# FcompresivasF_T1(BD)         1.388291    0.477997   0.34      1.388 (±0.48)
# FanteroposteiorF_T1(BD)      0.111870    0.240787   2.15      0.112 (±0.24)
# FmedilateralesF_T1(BD)       0.004172    0.067129  16.09      0.004 (±0.07)
# ...                               ...         ...    ...                ...
# FanteroposteiorF_1_T3(NW)  130.898667  186.521782   1.42  130.899 (±186.52)
# FmedilateralesF_1_T3(NW)    19.010066   35.702293   1.88      19.01 (±35.7)
# FcompresivasP_1_T3(NW)     109.941697  245.938576   2.24  109.942 (±245.94)
# FanteroposteiorP_1_T3(NW)   24.034823  347.022418  14.44   24.035 (±347.02)
# FmedilateralesP_1_T3(NW)   -30.429569   36.818369   1.21    -30.43 (±36.82)
#
# [79 rows x 4 columns]

# %%
import re
import numpy as np
import pandas as pd

# Mapeo de la cadena del eje → nombre legible
eje_map = {
    'compresivas'    : 'Compresivas',
    'anteroposteior' : 'Anteroposteior',
    'medilaterales'  : 'Medio-lateral'
}

# Unidades
unidad_map = {'BD': 'BW', 'NW': 'N'}

# Expresión regular para desmenuzar el índice
#  Ej.  FcompresivasF_T1(BD)  o  FanteroposteiorP_1_T3(NW)
pat = re.compile(
    r'^F(?P<eje>compresivas|anteroposteior|medilaterales)'
    r'(?P<tipo>[FP])'               # F o P
    r'(?P<pierna>_1)?'                      # el “_1” (pierna I) si aparece
    r'_T(?P<trial>\d)'              # número de ensayo
    r'\((?P<unidad>BD|NW)\)$',
    flags=re.I
)
def build_formatted(df_stats: pd.DataFrame, tipo: str) -> pd.DataFrame:
    """
    Devuelve una tabla estilo formatted_df_3
    solo con fuerzas del tipo 'F' o 'P'.
    """
    filas = []
    fases = ['F1', 'F2', 'F3']
    # Rodillas por fase
    rod_d = {f: df_stats.loc[f'{f}-RODSAGITAL D', 'media(ds)'] for f in fases}
    rod_i = {f: df_stats.loc[f'{f}-RODSAGITAL I', 'media(ds)'] for f in fases}

    # Agrupación de fuerzas por clave (fase, eje, unidad)
    grouped = {}
    for idx in df_stats.index:
        m = pat.match(idx)
        if not m or m['tipo'].upper() != tipo.upper():
            continue

        fase = f"F{m['trial']}"
        eje  = eje_map[m['eje'].lower()]
        met  = unidad_map[m['unidad']]
        pierna = 'I' if m['pierna'] else 'D'

        clave = (fase, eje, met)
        if clave not in grouped:
            grouped[clave] = {}
        grouped[clave][pierna] = {
            'media(ds)': df_stats.loc[idx, 'media(ds)'],
            'cv': df_stats.loc[idx, 'cv']
        }

    # Construcción de filas formateadas
    for (fase, eje, met), datos in grouped.items():
        rd_val = datos.get('D', {}).get('media(ds)', '')
        ri_val = datos.get('I', {}).get('media(ds)', '')
        rd_cv  = datos.get('D', {}).get('cv', np.nan)
        ri_cv  = datos.get('I', {}).get('cv', np.nan)

        filas.append({
            'FASE': fase,
            'RDM': rod_d[fase],
            'RIM': rod_i[fase],
            'EJE': eje,
            'MÉTRICA': met,
            'RDM_GR': rd_val,
            'RIM_GR': ri_val
        })

        filas.append({
            'FASE': '', 'RDP': '', 'RIP': '', 'EJE': '',
            'MÉTRICA': 'CV',
            'RDM_GR': f"{rd_cv*100:.2f}%" if not np.isnan(rd_cv) else '',
            'RIM_GR': f"{ri_cv*100:.2f}%" if not np.isnan(ri_cv) else ''
        })

    cols = ['FASE', 'RDM', 'RIM', 'EJE', 'MÉTRICA', 'RDM_GR', 'RIM_GR']
    return pd.DataFrame(filas, columns=cols).reset_index(drop=True)

formatted_F = build_formatted(df_stas, 'F')   # fuerzas F
formatted_P = build_formatted(df_stas, 'P')   # fuerzas P

print('Tabla fuerzas F')
display(formatted_F)

print('Tabla fuerzas P')
display(formatted_P)
# Out:
# Tabla fuerzas F
#    FASE              RDM             RIM             EJE MÉTRICA  \
# 0    F1    5.069 (±3.58)   6.041 (±4.45)     Compresivas      BW
# 1                    NaN             NaN                      CV
# 2    F1    5.069 (±3.58)   6.041 (±4.45)  Anteroposteior      BW
# 3                    NaN             NaN                      CV
# 4    F1    5.069 (±3.58)   6.041 (±4.45)   Medio-lateral      BW
# 5                    NaN             NaN                      CV
# 6    F2  73.595 (±10.23)  74.834 (±9.04)     Compresivas      BW
# 7                    NaN             NaN                      CV
# 8    F2  73.595 (±10.23)  74.834 (±9.04)  Anteroposteior      BW
# 9                    NaN             NaN                      CV
# 10   F2  73.595 (±10.23)  74.834 (±9.04)   Medio-lateral      BW
# 11                   NaN             NaN                      CV
# 12   F3    7.474 (±4.76)   6.491 (±4.68)     Compresivas      BW
# 13                   NaN             NaN                      CV
# 14   F3    7.474 (±4.76)   6.491 (±4.68)  Anteroposteior      BW
# 15                   NaN             NaN                      CV
# 16   F3    7.474 (±4.76)   6.491 (±4.68)   Medio-lateral      BW
# 17                   NaN             NaN                      CV
# 18   F1    5.069 (±3.58)   6.041 (±4.45)     Compresivas       N
# 19                   NaN             NaN                      CV
# 20   F1    5.069 (±3.58)   6.041 (±4.45)  Anteroposteior       N
# 21                   NaN             NaN                      CV
# 22   F1    5.069 (±3.58)   6.041 (±4.45)   Medio-lateral       N
# 23                   NaN             NaN                      CV
# 24   F2  73.595 (±10.23)  74.834 (±9.04)     Compresivas       N
# 25                   NaN             NaN                      CV
# 26   F2  73.595 (±10.23)  74.834 (±9.04)  Anteroposteior       N
# 27                   NaN             NaN                      CV
# 28   F2  73.595 (±10.23)  74.834 (±9.04)   Medio-lateral       N
# 29                   NaN             NaN                      CV
# 30   F3    7.474 (±4.76)   6.491 (±4.68)     Compresivas       N
# 31                   NaN             NaN                      CV
# 32   F3    7.474 (±4.76)   6.491 (±4.68)  Anteroposteior       N
# 33                   NaN             NaN                      CV
# 34   F3    7.474 (±4.76)   6.491 (±4.68)   Medio-lateral       N
# 35                   NaN             NaN                      CV
#
#                 RDM_GR              RIM_GR
# 0        1.639 (±1.19)        1.831 (±1.2)
# 1               73.00%              65.00%
# 2        0.298 (±0.34)        0.352 (±0.4)
# 3              114.00%             113.00%
# 4       -0.037 (±0.05)       0.044 (±0.05)
# 5              126.00%             108.00%
# 6        4.574 (±1.29)       3.506 (±1.18)
# 7               28.00%              34.00%
# 8        -1.53 (±0.81)      -1.109 (±0.51)
# 9               53.00%              46.00%
# 10        0.298 (±0.2)      -0.259 (±0.29)
# 11              68.00%             110.00%
# 12       1.785 (±1.12)       1.718 (±1.11)
# 13              63.00%              65.00%
# 14       0.237 (±0.45)       0.238 (±0.41)
# 15             188.00%             172.00%
# 16      -0.034 (±0.07)        0.03 (±0.08)
# 17             209.00%             255.00%
# 18   947.335 (±655.15)  1064.303 (±669.86)
# 19              69.00%              63.00%
# 20   169.156 (±185.29)   201.583 (±227.13)
# 21             110.00%             113.00%
# 22     -21.01 (±27.05)     25.194 (±27.54)
# 23             129.00%             109.00%
# 24  2696.309 (±793.25)  2087.643 (±770.46)
# 25              29.00%              37.00%
# 26  -900.309 (±472.28)  -660.817 (±321.07)
# 27              52.00%              49.00%
# 28   179.055 (±124.93)   -158.15 (±169.62)
# 29              70.00%             107.00%
# 30  1041.774 (±648.76)  1006.862 (±637.19)
# 31              62.00%              63.00%
# 32    131.569 (±273.3)   134.153 (±243.01)
# 33             208.00%             181.00%
# 34     -18.926 (±44.5)     15.782 (±46.14)
# 35             235.00%             292.00%
# Tabla fuerzas P
#    FASE              RDM             RIM             EJE MÉTRICA  \
# 0    F1    5.069 (±3.58)   6.041 (±4.45)  Anteroposteior      BW
# 1                    NaN             NaN                      CV
# 2    F1    5.069 (±3.58)   6.041 (±4.45)   Medio-lateral      BW
# 3                    NaN             NaN                      CV
# 4    F1    5.069 (±3.58)   6.041 (±4.45)     Compresivas      BW
# 5                    NaN             NaN                      CV
# 6    F2  73.595 (±10.23)  74.834 (±9.04)     Compresivas      BW
# 7                    NaN             NaN                      CV
# 8    F2  73.595 (±10.23)  74.834 (±9.04)  Anteroposteior      BW
# 9                    NaN             NaN                      CV
# 10   F2  73.595 (±10.23)  74.834 (±9.04)   Medio-lateral      BW
# 11                   NaN             NaN                      CV
# 12   F3    7.474 (±4.76)   6.491 (±4.68)     Compresivas      BW
# 13                   NaN             NaN                      CV
# 14   F3    7.474 (±4.76)   6.491 (±4.68)  Anteroposteior      BW
# 15                   NaN             NaN                      CV
# 16   F3    7.474 (±4.76)   6.491 (±4.68)   Medio-lateral      BW
# 17                   NaN             NaN                      CV
# 18   F1    5.069 (±3.58)   6.041 (±4.45)     Compresivas       N
# 19                   NaN             NaN                      CV
# 20   F1    5.069 (±3.58)   6.041 (±4.45)  Anteroposteior       N
# 21                   NaN             NaN                      CV
# 22   F1    5.069 (±3.58)   6.041 (±4.45)   Medio-lateral       N
# 23                   NaN             NaN                      CV
# 24   F2  73.595 (±10.23)  74.834 (±9.04)     Compresivas       N
# 25                   NaN             NaN                      CV
# 26   F2  73.595 (±10.23)  74.834 (±9.04)  Anteroposteior       N
# 27                   NaN             NaN                      CV
# 28   F2  73.595 (±10.23)  74.834 (±9.04)   Medio-lateral       N
# 29                   NaN             NaN                      CV
# 30   F3    7.474 (±4.76)   6.491 (±4.68)     Compresivas       N
# 31                   NaN             NaN                      CV
# 32   F3    7.474 (±4.76)   6.491 (±4.68)  Anteroposteior       N
# 33                   NaN             NaN                      CV
# 34   F3    7.474 (±4.76)   6.491 (±4.68)   Medio-lateral       N
# 35                   NaN             NaN                      CV
#
#                   RDM_GR               RIM_GR
# 0         -0.113 (±0.06)       -0.106 (±0.07)
# 1                 55.00%               70.00%
# 2          0.025 (±0.01)       -0.025 (±0.01)
# 3                 42.00%               21.00%
# 4                               0.004 (±0.01)
# 5                                     216.00%
# 6          -1.841 (±1.1)       -1.376 (±0.94)
# 7                 60.00%               69.00%
# 8         -3.835 (±1.69)       -2.906 (±1.58)
# 9                 44.00%               54.00%
# 10        -0.397 (±0.24)        0.288 (±0.18)
# 11                60.00%               63.00%
# 12        -0.045 (±0.23)       -0.027 (±0.16)
# 13               519.00%              575.00%
# 14        -0.223 (±0.62)         -0.2 (±0.45)
# 15               278.00%              225.00%
# 16         0.008 (±0.07)       -0.015 (±0.04)
# 17               931.00%              287.00%
# 18         2.981 (±4.39)        2.257 (±4.82)
# 19               147.00%              214.00%
# 20      -66.863 (±37.35)     -63.436 (±47.03)
# 21                56.00%               74.00%
# 22        14.597 (±5.23)       -14.662 (±2.9)
# 23                36.00%               20.00%
# 24   -1090.173 (±662.64)   -825.742 (±579.69)
# 25                61.00%               70.00%
# 26  -2269.598 (±1031.75)  -1742.486 (±987.79)
# 27                45.00%               57.00%
# 28     -235.34 (±141.83)    173.022 (±113.47)
# 29                60.00%               66.00%
# 30     -29.672 (±153.06)    -18.249 (±103.78)
# 31               516.00%              569.00%
# 32    -139.678 (±407.82)   -125.166 (±296.85)
# 33               292.00%              237.00%
# 34        3.291 (±46.65)      -8.544 (±28.84)
# 35              1417.00%              338.00%

# %%
with pd.ExcelWriter('tablas_af/Tablas_NW.xlsx', engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
    formatted_F.to_excel(writer, sheet_name='fuerzas_med f', index=True)

# %%
with pd.ExcelWriter('tablas_af/Tablas_NW.xlsx', engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
    formatted_P.to_excel(writer, sheet_name='fuerzas_med p', index=True)

# %%
import re

# ---------- utilidades ----------
def parse_val_sd(texto):
    """
    Extrae media y desviación estándar de un string tipo '0.51 (±0.10)'
    """
    m = re.match(r'\s*([+-]?\d+(?:\.\d+)?)\s*\(±\s*([+-]?\d+(?:\.\d+)?)\s*\)', str(texto))
    return (float(m.group(1)), float(m.group(2))) if m else (np.nan, np.nan)

def fmt(mean, sd, dec=2):
    """Devuelve 'media (±sd)' con n decimales."""
    return f"{mean:.{dec}f} (±{sd:.{dec}f})"

def fmt_cv(cv):               # cv en fracción → porcentaje
    return f"{cv*100:.2f}%"

# ---------- parámetros ----------
fases        = ['F1', 'F2', 'F3']
ejes_cod     = {'VGRFY': 'Vertical', 'VGRFX': 'Anteroposterior', 'VGRFZ': 'Medio-lateral'}
piernas      = {'D': 'RD', 'I': 'RI'}
unidades_map = {'(%BW)': 'BW', '(NEWTON)': 'N'}

# ---------- generación ----------
filas = []
for fase in fases:
    # rodillas en sagital
    rd_rod = df_stas.loc[f"{fase}-RODSAGITAL D", 'media(ds)']
    ri_rod = df_stas.loc[f"{fase}-RODSAGITAL I", 'media(ds)']

    # recorre cada eje
    for cod_eje, nombre_eje in ejes_cod.items():
        # -------------------- BW y N --------------------
        for sufijo, etiqueta in unidades_map.items():
            # valores por pierna
            rd_idx = f"{fase}-{cod_eje} D {sufijo}"
            ri_idx = f"{fase}-{cod_eje} I {sufijo}"
            

            rd_val = df_stas.loc[rd_idx, 'media(ds)'] if rd_idx in df_stas.index else None
            ri_val = df_stas.loc[ri_idx, 'media(ds)'] if ri_idx in df_stas.index else None

            # calcula total y diferencia si faltan
            # if rd_val and ri_val:
            #     m_rd, s_rd = parse_val_sd(rd_val)
            #     m_ri, s_ri = parse_val_sd(ri_val)

            #     if not tot_val:
            #         tot_val = fmt(m_rd + m_ri, (s_rd**2 + s_ri**2) ** 0.5)
            #     if not diff_val:
            #         diff_val = fmt(abs(m_rd - m_ri), (s_rd**2 + s_ri**2) ** 0.5)

            # ---------- fila BW / N ----------
            filas.append({
                'FASE': fase,
                'RD': rd_rod,
                'RI': ri_rod,
                'EJE': nombre_eje,
                'MÉTRICA': etiqueta,
                'RD_GR': rd_val,
                'RI_GR': ri_val,
            })

            # ---------- fila CV ----------
            rd_cv = df_stas.loc[rd_idx, 'cv'] if rd_idx in df_stas.index else np.nan
            ri_cv = df_stas.loc[ri_idx, 'cv'] if ri_idx in df_stas.index else np.nan
            filas.append({
                'FASE': '',
                'RD': '',
                'RI': '',
                'EJE': '',
                'MÉTRICA': 'CV',
                'RD_GR': fmt_cv(rd_cv) if not np.isnan(rd_cv) else '',
                'RI_GR': fmt_cv(ri_cv) if not np.isnan(ri_cv) else '',
            })

# ---------- DataFrame final ----------
cols = ['FASE', 'RD', 'RI', 'EJE', 'MÉTRICA',
        'RD_GR', 'RI_GR']
formatted_df_3 = pd.DataFrame(filas, columns=cols)

# opcional: elimina filas con métricas vacías si fuera necesario
formatted_df_3 = formatted_df_3.dropna(subset=['RD_GR', 'RI_GR'], how='all').reset_index(drop=True)
formatted_df_3
